# %% [markdown]
# Rename a file in Python:

# %%
import os

current_file_name = "old_file.txt"
new_file_name = "new_file.txt"

try:
    os.rename(current_file_name, new_file_name)
    print(f"File '{current_file_name}' renamed to '{new_file_name}' successfully.")
except FileNotFoundError:
    print(f"Error: The file '{current_file_name}' was not found.")
except FileExistsError:
    print(f"Error: The destination file '{new_file_name}' already exists.")
except PermissionError:
    print("Error: Permission denied. Unable to rename the file.")

# %% [markdown]
# Loop over all files in a directory

# %%
from pathlib import Path
import os # os module is used here only for getting the current working directory path

# Define the directory path
directory_path = Path.cwd() # Use Path.cwd() for the current working directory
# or specify a path directly: directory_path = Path("my_folder")

print(f"Looping through files in: {directory_path}")

for file_path in directory_path.iterdir():
    if file_path.is_file():
        print(file_path.name) # Print only the file name
        # To get the full path, simply print the file_path object itself
